# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from matplotlib import colormaps

sys.path.append("C:/Users/haoyu/Documents/GitHub/XRaySimulation")

from XRaySimulation import Pulse, DeviceSimu, util, Crystal

# %%
bLattice = np.zeros((11, 11, 11, 3600, 3))

bLattice[:,:,:,:,0] = np.arange(-5, 6)[:, np.newaxis, np.newaxis, np.newaxis] * np.pi * 2 / 3.9050 * 1e4
bLattice[:,:,:,:,1] = np.arange(-5, 6)[np.newaxis, :, np.newaxis, np.newaxis] * np.pi * 2 / 3.9050 * 1e4
bLattice[:,:,:,:,2] = np.arange(-5, 6)[np.newaxis, np.newaxis, :, np.newaxis] * np.pi * 2 / 3.9050 * 1e4

tilt_angle = np.deg2rad(0)
tilt_mat = np.array([
    [1, 0, 0,],
    [0, np.cos(tilt_angle), -np.sin(tilt_angle)],
    [0, np.sin(tilt_angle), np.cos(tilt_angle)],
])

for xIdx in range(11):
    for yIdx in range(11):
        for zIdx in range(11):
            for idx in range(3600):
                angle = np.deg2rad(idx) / 10
                rot_mat = np.array([[np.cos(angle), 0, -np.sin(angle)],
                                    [0, 1, 0],
                                    [np.sin(angle), 0, np.cos(angle)],])
                
                bLattice[xIdx, yIdx, zIdx, idx, :] = np.dot(tilt_mat, np.dot(rot_mat, bLattice[xIdx, yIdx, zIdx, idx]))

# %%
kLen = util.kev_to_wavevec_length(9.8)
angle = np.deg2rad(11.639) * 2
kvec = np.array([-np.sin(angle), 0, np.cos(angle)]) * kLen

tg_angle = np.deg2rad(0.4)
kvec_tg = np.copy(kvec)
kvec_tg[1] += 2 * np.sin(tg_angle) * kLen

# %%
kout = bLattice + kvec_tg[np.newaxis, np.newaxis, np.newaxis, np.newaxis]
kout_len = np.linalg.norm(kout, axis=-1)
kout_len_diff = kout_len - kLen

# %%
fig, ax = plt.subplots(ncols=1,nrows=1)
cmap = colormaps['summer']

fig.set_figheight(5)
fig.set_figwidth(10)

for xIdx in range(11):
    for yIdx in range(11):
        for zIdx in range(11):
            ax.plot(np.arange(3600) / 10, kout_len_diff[xIdx, yIdx, zIdx] / 1e4,
                    label="G=({}, {}, {})".format(xIdx, yIdx, zIdx))

plt.title('|K + tg + G| - |K|')
plt.ylabel("A^-1")
plt.xlabel('angle deg')
#plt.legend()
plt.show()

# %%
for xIdx in range(11):
    for yIdx in range(11):
        for zIdx in range(11):
            x = np.argmin(np.abs(kout_len_diff[xIdx, yIdx, zIdx] / 1e4))
            k_tmp = kout[xIdx, yIdx, zIdx, x]
            
            if x == 3599:
                continue
                            
            if kout_len_diff[xIdx, yIdx, zIdx, x - 1] *  kout_len_diff[xIdx, yIdx, zIdx, x + 1] < 0:
                
                if k_tmp[0] > 0 and k_tmp[1] > 0 and k_tmp[2] > 0:
                    # Normalize the wave-vector
                        direction = k_tmp / np.linalg.norm(k_tmp)
                
                        # Get the position
                        position = direction / direction[2] * 12

                        # Impose the det position limitation
                        if position[0] < 15 and position[1]<18:
                            if xIdx - 5 >= 0 and yIdx - 5>= 0 and zIdx - 5>= 0 :

                                print("G=({}, {}, {})".format(xIdx - 5, yIdx - 5, zIdx - 5), kout[xIdx, yIdx, zIdx, x], x / 10 + 1 - 270)
                                print("detector positoin with respect to the sample in cm", position)
                                print('------------------------------')
# Out:
# G=(0, 0, 3) [28396.43818647   693.43129194 40743.02271628] -4.800000000000011
# detector positoin with respect to the sample in cm [ 8.36357333  0.2042356  12.        ]
# ------------------------------
# G=(0, 2, 2) [10943.53502748 32873.63773076 35570.03931844] -17.19999999999999
# detector positoin with respect to the sample in cm [ 3.69193914 11.09033502 12.        ]
# ------------------------------
# G=(1, 0, 1) [ 2782.38330842   693.43129194 49572.37835411] 56.0
# detector positoin with respect to the sample in cm [ 0.67353233  0.16785911 12.        ]
# ------------------------------
# G=(1, 0, 2) [16329.11310191   693.43129194 46898.60758381] 29.600000000000023
# detector positoin with respect to the sample in cm [ 4.17814872  0.17742905 12.        ]
# ------------------------------
# G=(1, 0, 3) [30815.25462779   693.43129194 38948.92001782] 11.899999999999977
# detector positoin with respect to the sample in cm [ 9.49405158  0.21364329 12.        ]
# ------------------------------
# G=(1, 1, 3) [30262.16874262 16783.53451135 35620.5997222 ] 8.100000000000023
# detector positoin with respect to the sample in cm [10.19483186  5.65409947 12.        ]
# ------------------------------
# G=(2, 0, 1) [16328.43692518   693.43129194 46917.49809083] 66.5
# detector positoin with respect to the sample in cm [ 4.17629352  0.17735761 12.        ]
# ------------------------------
# G=(2, 0, 2) [25772.0633802    693.43129194 42446.44637026] 42.0
# detector positoin with respect to the sample in cm [ 7.28599888  0.19603939 12.        ]
# ------------------------------
# G=(2, 1, 2) [25428.90249541 16783.53451135 39208.67087918] 37.89999999999998
# detector positoin with respect to the sample in cm [ 7.78263642  5.13668047 12.        ]
# ------------------------------
# G=(2, 1, 3) [36142.34966269 16783.53451135 29639.96833838] 18.69999999999999
# detector positoin with respect to the sample in cm [14.63254586  6.7949605  12.        ]
# ------------------------------
# G=(2, 2, 0) [10943.53502748 32873.63773076 35570.03931844] 72.80000000000001
# detector positoin with respect to the sample in cm [ 3.69193914 11.09033502 12.        ]
# ------------------------------
# G=(3, 0, 0) [28396.43818647   693.43129194 40743.02271628] 85.19999999999999
# detector positoin with respect to the sample in cm [ 8.36357333  0.2042356  12.        ]
# ------------------------------
# G=(3, 0, 1) [30811.74223239   693.43129194 38922.41945142] 65.0
# detector positoin with respect to the sample in cm [ 9.49943277  0.21378875 12.        ]
# ------------------------------
# G=(3, 1, 1) [30256.90777343 16783.53451135 35594.39019829] 61.19999999999999
# detector positoin with respect to the sample in cm [10.20056507  5.65826281 12.        ]
# ------------------------------
# G=(3, 1, 2) [36136.80553301 16783.53451135 29620.63366045] 41.30000000000001
# detector positoin with respect to the sample in cm [14.6398511   6.79939587 12.        ]
# ------------------------------
