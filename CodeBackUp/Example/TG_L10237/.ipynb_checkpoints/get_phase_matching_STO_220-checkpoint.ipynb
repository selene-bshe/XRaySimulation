# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from matplotlib import colormaps

sys.path.append("C:/Users/haoyu/Documents/GitHub/XRaySimulation")

from XRaySimulation import Pulse, DeviceSimu, util, Crystal

# %%
bLattice = np.zeros((11, 11, 11, 360, 3))

bLattice[:,:,:,:,0] = np.arange(-5, 6)[:, np.newaxis, np.newaxis, np.newaxis] * np.pi * 2 / 3.9050 * 1e4
bLattice[:,:,:,:,1] = np.arange(-5, 6)[np.newaxis, :, np.newaxis, np.newaxis] * np.pi * 2 / 3.9050 * 1e4
bLattice[:,:,:,:,2] = np.arange(-5, 6)[np.newaxis, np.newaxis, :, np.newaxis] * np.pi * 2 / 3.9050 * 1e4

tilt_angle = np.deg2rad(0)
tilt_mat = np.array([
    [1, 0, 0,],
    [0, np.cos(tilt_angle), -np.sin(tilt_angle)],
    [0, np.sin(tilt_angle), np.cos(tilt_angle)],
])

for xIdx in range(11):
    for yIdx in range(11):
        for zIdx in range(11):
            for idx in range(360):
                angle = np.deg2rad(idx)
                rot_mat = np.array([[np.cos(angle), 0, -np.sin(angle)],
                                    [0, 1, 0],
                                    [np.sin(angle), 0, np.cos(angle)],])
                
                bLattice[xIdx, yIdx, zIdx, idx, :] = np.dot(tilt_mat, np.dot(rot_mat, bLattice[xIdx, yIdx, zIdx, idx]))

# %%
kLen = util.kev_to_wavevec_length(9.8)
angle = np.deg2rad(11.639) * 2
kvec = np.array([-np.sin(angle), 0, np.cos(angle)]) * kLen

tg_angle = np.deg2rad(0.4)
kvec_tg = np.copy(kvec)
kvec_tg[1] += 2 * np.sin(tg_angle) * kLen

# %%
kout = bLattice + kvec_tg[np.newaxis, np.newaxis, np.newaxis, np.newaxis]
kout_len = np.linalg.norm(kout, axis=-1)
kout_len_diff = kout_len - kLen

# %%
fig, ax = plt.subplots(ncols=1,nrows=1)
cmap = colormaps['summer']

fig.set_figheight(5)
fig.set_figwidth(10)

for xIdx in range(11):
    for yIdx in range(11):
        for zIdx in range(11):
            ax.plot(np.arange(360), kout_len_diff[xIdx, yIdx, zIdx] / 1e4,
                    label="G=({}, {}, {})".format(xIdx, yIdx, zIdx))

plt.title('|K + tg + G| - |K|')
plt.ylabel("A^-1")
plt.xlabel('angle deg')
#plt.legend()
plt.show()

# %%
for xIdx in range(11):
    for yIdx in range(11):
        for zIdx in range(11):
            x = np.argmin(np.abs(kout_len_diff[xIdx, yIdx, zIdx] / 1e4))
            k_tmp = kout[xIdx, yIdx, zIdx, x]
            
            if x == 359:
                continue
                            
            if kout_len_diff[xIdx, yIdx, zIdx, x - 1] *  kout_len_diff[xIdx, yIdx, zIdx, x + 1] < 0:
                
                if k_tmp[0] > 0 and k_tmp[1] > 0 and k_tmp[2] > 0:
                    # Normalize the wave-vector
                        direction = k_tmp / np.linalg.norm(k_tmp)
                
                        # Get the position
                        position = direction / direction[2] * 12

                        # Impose the det position limitation
                        if position[0] < 15 and position[1]<18:
                            if xIdx - 5 >= 0 and yIdx - 5>= 0 and zIdx - 5>= 0 :

                                print("G=({}, {}, {})".format(xIdx - 5, yIdx - 5, zIdx - 5), kout[xIdx, yIdx, zIdx, x], x + 1 - 270)
                                print("detector positoin with respect to the sample in cm", position)
                                print('------------------------------')
# Out:
# G=(0, 0, 3) [28379.11814962   693.43129194 40575.42018419] -5
# detector positoin with respect to the sample in cm [ 8.39299793  0.20507922 12.        ]
# ------------------------------
# G=(0, 1, 2) [12548.54353582 16783.53451135 45059.41943221] 0
# detector positoin with respect to the sample in cm [ 3.34186557  4.46970726 12.        ]
# ------------------------------
# G=(0, 1, 3) [27910.21349003 16783.53451135 37238.99016665] -9
# detector positoin with respect to the sample in cm [ 8.993868    5.40837475 12.        ]
# ------------------------------
# G=(0, 2, 2) [10978.43332767 32873.63773076 35676.81080213] -17
# detector positoin with respect to the sample in cm [ 3.69262826 11.05714451 12.        ]
# ------------------------------
# G=(0, 2, 3) [25128.69006836 32873.63773076 27538.66521002] -21
# detector positoin with respect to the sample in cm [10.949851   14.32471944 12.        ]
# ------------------------------
# G=(1, 0, 1) [ 2782.38330842   693.43129194 49572.37835411] 56
# detector positoin with respect to the sample in cm [ 0.67353233  0.16785911 12.        ]
# ------------------------------
# G=(1, 0, 3) [30826.82284306   693.43129194 39036.96806197] 12
# detector positoin with respect to the sample in cm [ 9.47619378  0.21316142 12.        ]
# ------------------------------
# G=(1, 1, 3) [30244.63870279 16783.53451135 35533.54238829] 8
# detector positoin with respect to the sample in cm [10.21388919  5.66795204 12.        ]
# ------------------------------
# G=(1, 2, 1) [ 1471.16059275 32873.63773076 37096.92755663] 24
# detector positoin with respect to the sample in cm [ 0.4758865 10.6338632 12.       ]
# ------------------------------
# G=(1, 2, 2) [14479.57874    32873.63773076 34166.14515291] 9
# detector positoin with respect to the sample in cm [ 5.08558821 11.54603924 12.        ]
# ------------------------------
# G=(1, 2, 3) [27057.51995811 32873.63773076 25385.13126437] -4
# detector positoin with respect to the sample in cm [12.79056768 15.5399493  12.        ]
# ------------------------------
# G=(2, 0, 2) [25772.0633802    693.43129194 42446.44637026] 42
# detector positoin with respect to the sample in cm [ 7.28599888  0.19603939 12.        ]
# ------------------------------
# G=(2, 0, 3) [36969.80917361   693.43129194 32876.76251843] 22
# detector positoin with respect to the sample in cm [13.49395975  0.25310204 12.        ]
# ------------------------------
# G=(2, 1, 2) [25440.02556402 16783.53451135 39287.31757454] 38
# detector positoin with respect to the sample in cm [ 7.77045433  5.12639769 12.        ]
# ------------------------------
# G=(2, 2, 0) [10978.43332767 32873.63773076 35676.81080213] 73
# detector positoin with respect to the sample in cm [ 3.69262826 11.05714451 12.        ]
# ------------------------------
# G=(2, 2, 1) [14505.50158762 32873.63773076 34243.62037778] 46
# detector positoin with respect to the sample in cm [ 5.08316636 11.51991666 12.        ]
# ------------------------------
# G=(2, 2, 2) [22860.1888569  32873.63773076 29311.82919645] 25
# detector positoin with respect to the sample in cm [ 9.3587563  13.45817247 12.        ]
# ------------------------------
# G=(3, 0, 0) [28379.11814962   693.43129194 40575.42018419] 85
# detector positoin with respect to the sample in cm [ 8.39299793  0.20507922 12.        ]
# ------------------------------
# G=(3, 0, 1) [30811.74223239   693.43129194 38922.41945142] 65
# detector positoin with respect to the sample in cm [ 9.49943277  0.21378875 12.        ]
# ------------------------------
# G=(3, 0, 2) [37053.1162216    693.43129194 33252.53632821] 45
# detector positoin with respect to the sample in cm [13.37153323  0.25024183 12.        ]
# ------------------------------
# G=(3, 1, 0) [27910.21349003 16783.53451135 37238.99016665] 81
# detector positoin with respect to the sample in cm [ 8.993868    5.40837475 12.        ]
# ------------------------------
# G=(3, 1, 1) [30221.60432058 16783.53451135 35420.32478263] 61
# detector positoin with respect to the sample in cm [10.2387331  5.6860691 12.       ]
# ------------------------------
# G=(3, 2, 0) [25128.69006836 32873.63773076 27538.66521002] 69
# detector positoin with respect to the sample in cm [10.949851   14.32471944 12.        ]
# ------------------------------
# G=(3, 2, 1) [27011.44966859 32873.63773076 25279.17685238] 49
# detector positoin with respect to the sample in cm [12.82230818 15.60508299 12.        ]
# ------------------------------
